# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('D:/Dsbda_Lab/employees.csv')

# %%
data.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
bool_series=pd.isnull(data['Team'])

# %%
bool_series
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
data.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data['Gender'].fillna('No Gender',inplace=True)

# %%
data[40:56]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 40    Michael       Male  10/10/2008        11:25 AM   99283    2.665
# 41  Christine  No Gender   6/28/2015         1:08 AM   66582   11.308
# 42    Beverly     Female    9/9/1998         8:26 PM  121918   15.835
# 43    Marilyn     Female   12/7/1980         3:16 AM   73524    5.207
# 44    Cynthia     Female  11/16/1988         6:54 PM  145146    7.482
# 45      Roger       Male   4/17/1980        11:32 AM   88010   13.886
# 46      Bruce       Male  11/28/2009        10:47 PM  114796    6.796
# 47      Kathy     Female   6/22/2005         4:51 AM   66820    9.000
# 48   Clarence       Male   3/26/1996         5:57 AM   93581    6.083
# 49      Chris  No Gender   1/24/1980        12:13 PM  113590    3.055
# 50      Nancy     Female   9/23/2000         8:05 AM   94976   13.830
# 51        NaN  No Gender  12/17/2011         8:29 AM   41126   14.009
# ...

# %%
data['Senior Management'].fillna('Mgmnt',inplace=True)

# %%
data[25:40]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 25        NaN       Male   10/8/2012         1:12 AM   37076   18.576
# 26      Craig       Male   2/27/2000         7:45 AM   37598    7.757
# 27      Scott  No Gender   7/11/1991         6:58 PM  122367    5.218
# 28      Terry       Male  11/27/1981         6:30 PM  124008   13.464
# 29   Benjamin       Male   1/26/2005        10:06 PM   79529    7.008
# 30  Christina     Female    8/6/2002         1:19 PM  118780    9.096
# 31      Joyce  No Gender   2/20/2005         2:40 PM   88657   12.752
# 32        NaN       Male   8/21/1998         2:27 PM  122340    6.417
# 33       Jean     Female  12/18/1993         9:07 AM  119082   16.180
# 34      Jerry       Male   1/10/2004        12:56 PM   95734   19.096
# 35    Theresa     Female  10/10/2006         1:12 AM   85182   16.675
# 36     Rachel     Female   2/16/2009         8:47 PM  142032   12.599
# ...

# %%
data[10:26]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
# '''data['Team'].fillna('No Team',inplace=True)'''

bfill=data.fillna(method='bfill')
bfill[10:26]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
data[10:30]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
data.fillna(method='pad',inplace=True) #previous data is filled with NaN Values
data[10:26]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# ...

# %%
data.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
data.hist('Salary')
# Out:
# array([[<AxesSubplot:title={'center':'Salary'}>]], dtype=object)

# %%
data.boxplot('Salary')
# Out:
# <AxesSubplot:>
